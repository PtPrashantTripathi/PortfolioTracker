# %% [markdown]
# ## SOURCE TO BRONZE LAYER
#
# > This Notebook reads the RAW files and performs data harmonization.

# %%
# Import necessary libraries and utility functions
import yfinance as yf
from common.utilities import (
    fix_duplicate_column_names,
    global_path,
    replace_punctuation_from_columns,
    logger,
)

# %%
def process_file(symbol: str, filename: str) -> None:
    """
    Processes historical stock data for a given symbol and saves it to a CSV file.

    Parameters:
    - symbol (str): The stock symbol to fetch data for.
    - filename (str): The filename to save the processed data as.
    """

    # Log the start of processing for the given symbol
    logger.info(f"Starting data processing for symbol: {symbol}")

    # Fetch historical stock data from Yahoo Finance
    stock = yf.Ticker(symbol)
    df = stock.history(start="2020-01-01", interval="1d")

    # Check if the DataFrame is empty
    if df.empty:
        logger.warning(f"No data fetched for symbol: {symbol}")
        return

    # Reset the index to ensure date is a column
    df = df.reset_index()

    # Replace punctuation in column names for consistency
    df = replace_punctuation_from_columns(df)

    # Fix duplicate column names by appending numerical suffixes
    df = fix_duplicate_column_names(df)

    # Determine the output file path in the bronze layer
    output_file = global_path.stockdata_bronze_layer_path.joinpath(filename)

    # Save the processed DataFrame to a CSV file
    df.to_csv(output_file, index=False)

    # Log successful processing and saving of data
    logger.info(
        f"Data for {symbol} successfully processed and saved to {output_file}"
    )

# %%
# Dictionary mapping stock symbols to output filenames
symbols_to_files = {
    "0P00017844.BO": "MIRAE-ASSET-TAX-SAVER-DIRECT-GROWTH.MF.csv",
    "0P0000XVL9.BO": "SBI-MAGNUM-TAXGAIN-SCHEME-DIR-GR.MF.csv",
    "BHAGERIA.NS": "BHAGERIA.NS.csv",
    "BPCL.NS": "BPCL.NS.csv",
    "GOLDBEES.NS": "GOLDBEES.NS.csv",
    "HERANBA.NS": "HERANBA.NS.csv",
    "IDEA.NS": "IDEA.NS.csv",
    "INFY.NS": "INFY.NS.csv",
    "IRCTC.NS": "IRCTC.NS.csv",
    "KPITTECH.NS": "KPITTECH.NS.csv",
    "LICI.NS": "LICI.NS.csv",
    "NIFTYBEES.NS": "NIFTYBEES.NS.csv",
    "PNB.NS": "PNB.NS.csv",
    "SBIN.NS": "SBIN.NS.csv",
    "TATACHEM.NS": "TATACHEM.NS.csv",
    "TATAMOTORS.NS": "TATAMOTORS.NS.csv",
    "TATAPOWER.NS": "TATAPOWER.NS.csv",
    "VOLTAS.NS": "VOLTAS.NS.csv",
    "YESBANK.NS": "YESBANK.NS.csv",
}

# Iterate over each symbol and corresponding filename
for symbol, filename in symbols_to_files.items():
    try:
        process_file(symbol, filename)
    except Exception as e:
        # Log any errors encountered during processing
        logger.error(f"Error processing data for {symbol}: {e}")
# Out:
# 2024-08-07T11:43:14Z - INFO - Starting data processing for symbol: 0P00017844.BO
# 2024-08-07T11:43:14Z - DEBUG - Entering history()
# 2024-08-07T11:43:15Z - DEBUG - 0P00017844.BO: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:15+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:15Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:15Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/0P00017844.BO?period1=1577817000&period2=1723011195&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:15Z - DEBUG - 0P00017844.BO: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-07 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:15Z - DEBUG - 0P00017844.BO: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-07 09:15:00+05:30
# 2024-08-07T11:43:15Z - DEBUG - 0P00017844.BO: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-07 00:00:00+05:30
# 2024-08-07T11:43:15Z - DEBUG - 0P00017844.BO: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:15Z - DEBUG - Exiting history()
# 2024-08-07T11:43:15Z - INFO - Data for 0P00017844.BO successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\MIRAE-ASSET-TAX-SAVER-DIRECT-GROWTH.MF.csv
# 2024-08-07T11:43:15Z - INFO - Starting data processing for symbol: 0P0000XVL9.BO
# 2024-08-07T11:43:15Z - DEBUG - Entering history()
# 2024-08-07T11:43:15Z - DEBUG - 0P0000XVL9.BO: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:15+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:15Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:15Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/0P0000XVL9.BO?period1=1577817000&period2=1723011195&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:15Z - DEBUG - 0P0000XVL9.BO: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-07 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:15Z - DEBUG - 0P0000XVL9.BO: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-07 09:15:00+05:30
# 2024-08-07T11:43:15Z - DEBUG - 0P0000XVL9.BO: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-07 00:00:00+05:30
# 2024-08-07T11:43:15Z - DEBUG - 0P0000XVL9.BO: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:15Z - DEBUG - Exiting history()
# 2024-08-07T11:43:15Z - INFO - Data for 0P0000XVL9.BO successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\SBI-MAGNUM-TAXGAIN-SCHEME-DIR-GR.MF.csv
# 2024-08-07T11:43:15Z - INFO - Starting data processing for symbol: BHAGERIA.NS
# 2024-08-07T11:43:15Z - DEBUG - Entering history()
# 2024-08-07T11:43:15Z - DEBUG - BHAGERIA.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:15+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:15Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:15Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/BHAGERIA.NS?period1=1577817000&period2=1723011195&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:15Z - DEBUG - BHAGERIA.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:15Z - DEBUG - BHAGERIA.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:15Z - DEBUG - BHAGERIA.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:15Z - DEBUG - BHAGERIA.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:15Z - DEBUG - Exiting history()
# 2024-08-07T11:43:16Z - INFO - Data for BHAGERIA.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\BHAGERIA.NS.csv
# 2024-08-07T11:43:16Z - INFO - Starting data processing for symbol: BPCL.NS
# 2024-08-07T11:43:16Z - DEBUG - Entering history()
# 2024-08-07T11:43:16Z - DEBUG - BPCL.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:16+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:16Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:16Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/BPCL.NS?period1=1577817000&period2=1723011196&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:16Z - DEBUG - BPCL.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:16Z - DEBUG - BPCL.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:16Z - DEBUG - BPCL.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:16Z - DEBUG - BPCL.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:16Z - DEBUG - Exiting history()
# 2024-08-07T11:43:16Z - INFO - Data for BPCL.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\BPCL.NS.csv
# 2024-08-07T11:43:16Z - INFO - Starting data processing for symbol: GOLDBEES.NS
# 2024-08-07T11:43:16Z - DEBUG - Entering history()
# 2024-08-07T11:43:16Z - DEBUG - GOLDBEES.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:16+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:16Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:16Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/GOLDBEES.NS?period1=1577817000&period2=1723011196&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:16Z - DEBUG - GOLDBEES.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:16Z - DEBUG - GOLDBEES.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:16Z - DEBUG - GOLDBEES.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:16Z - DEBUG - GOLDBEES.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:16Z - DEBUG - Exiting history()
# 2024-08-07T11:43:16Z - INFO - Data for GOLDBEES.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\GOLDBEES.NS.csv
# 2024-08-07T11:43:16Z - INFO - Starting data processing for symbol: HERANBA.NS
# 2024-08-07T11:43:16Z - DEBUG - Entering history()
# 2024-08-07T11:43:16Z - DEBUG - HERANBA.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:16+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:16Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:16Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/HERANBA.NS?period1=1577817000&period2=1723011196&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:16Z - DEBUG - HERANBA.NS: yfinance received OHLC data: 2021-03-05 03:45:00 -> 2024-08-07 06:13:05
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:16Z - DEBUG - HERANBA.NS: OHLC after cleaning: 2021-03-05 09:15:00+05:30 -> 2024-08-07 11:43:05+05:30
# 2024-08-07T11:43:16Z - DEBUG - HERANBA.NS: OHLC after combining events: 2021-03-05 00:00:00+05:30 -> 2024-08-07 00:00:00+05:30
# 2024-08-07T11:43:16Z - DEBUG - HERANBA.NS: yfinance returning OHLC: 2021-03-05 00:00:00+05:30 -> 2024-08-07 00:00:00+05:30
# 2024-08-07T11:43:16Z - DEBUG - Exiting history()
# 2024-08-07T11:43:17Z - INFO - Data for HERANBA.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\HERANBA.NS.csv
# 2024-08-07T11:43:17Z - INFO - Starting data processing for symbol: IDEA.NS
# 2024-08-07T11:43:17Z - DEBUG - Entering history()
# 2024-08-07T11:43:17Z - DEBUG - IDEA.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:17+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:17Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:17Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/IDEA.NS?period1=1577817000&period2=1723011197&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:17Z - DEBUG - IDEA.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:17Z - DEBUG - IDEA.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:17Z - DEBUG - IDEA.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:17Z - DEBUG - IDEA.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:17Z - DEBUG - Exiting history()
# 2024-08-07T11:43:17Z - INFO - Data for IDEA.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\IDEA.NS.csv
# 2024-08-07T11:43:17Z - INFO - Starting data processing for symbol: INFY.NS
# 2024-08-07T11:43:17Z - DEBUG - Entering history()
# 2024-08-07T11:43:17Z - DEBUG - INFY.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:17+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:17Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:17Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/INFY.NS?period1=1577817000&period2=1723011197&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:17Z - DEBUG - INFY.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:17Z - DEBUG - INFY.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:17Z - DEBUG - INFY.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:17Z - DEBUG - INFY.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:17Z - DEBUG - Exiting history()
# 2024-08-07T11:43:17Z - INFO - Data for INFY.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\INFY.NS.csv
# 2024-08-07T11:43:17Z - INFO - Starting data processing for symbol: IRCTC.NS
# 2024-08-07T11:43:17Z - DEBUG - Entering history()
# 2024-08-07T11:43:17Z - DEBUG - IRCTC.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:17+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:17Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:17Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/IRCTC.NS?period1=1577817000&period2=1723011197&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:18Z - DEBUG - IRCTC.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:18Z - DEBUG - IRCTC.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - IRCTC.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - IRCTC.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - Exiting history()
# 2024-08-07T11:43:18Z - INFO - Data for IRCTC.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\IRCTC.NS.csv
# 2024-08-07T11:43:18Z - INFO - Starting data processing for symbol: KPITTECH.NS
# 2024-08-07T11:43:18Z - DEBUG - Entering history()
# 2024-08-07T11:43:18Z - DEBUG - KPITTECH.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:18+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:18Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:18Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/KPITTECH.NS?period1=1577817000&period2=1723011198&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:18Z - DEBUG - KPITTECH.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:18Z - DEBUG - KPITTECH.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - KPITTECH.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - KPITTECH.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - Exiting history()
# 2024-08-07T11:43:18Z - INFO - Data for KPITTECH.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\KPITTECH.NS.csv
# 2024-08-07T11:43:18Z - INFO - Starting data processing for symbol: LICI.NS
# 2024-08-07T11:43:18Z - DEBUG - Entering history()
# 2024-08-07T11:43:18Z - DEBUG - LICI.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:18+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:18Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:18Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/LICI.NS?period1=1577817000&period2=1723011198&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:18Z - DEBUG - LICI.NS: yfinance received OHLC data: 2022-05-17 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:18Z - DEBUG - LICI.NS: OHLC after cleaning: 2022-05-17 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - LICI.NS: OHLC after combining events: 2022-05-17 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - LICI.NS: yfinance returning OHLC: 2022-05-17 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - Exiting history()
# 2024-08-07T11:43:18Z - INFO - Data for LICI.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\LICI.NS.csv
# 2024-08-07T11:43:18Z - INFO - Starting data processing for symbol: NIFTYBEES.NS
# 2024-08-07T11:43:18Z - DEBUG - Entering history()
# 2024-08-07T11:43:18Z - DEBUG - NIFTYBEES.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:18+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:18Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:18Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/NIFTYBEES.NS?period1=1577817000&period2=1723011198&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:18Z - DEBUG - NIFTYBEES.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:18Z - DEBUG - NIFTYBEES.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - NIFTYBEES.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - NIFTYBEES.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:18Z - DEBUG - Exiting history()
# 2024-08-07T11:43:18Z - INFO - Data for NIFTYBEES.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\NIFTYBEES.NS.csv
# 2024-08-07T11:43:18Z - INFO - Starting data processing for symbol: PNB.NS
# 2024-08-07T11:43:18Z - DEBUG - Entering history()
# 2024-08-07T11:43:18Z - DEBUG - PNB.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:18+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:18Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:19Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/PNB.NS?period1=1577817000&period2=1723011198&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:19Z - DEBUG - PNB.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:19Z - DEBUG - PNB.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:19Z - DEBUG - PNB.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:19Z - DEBUG - PNB.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:19Z - DEBUG - Exiting history()
# 2024-08-07T11:43:19Z - INFO - Data for PNB.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\PNB.NS.csv
# 2024-08-07T11:43:19Z - INFO - Starting data processing for symbol: SBIN.NS
# 2024-08-07T11:43:19Z - DEBUG - Entering history()
# 2024-08-07T11:43:19Z - DEBUG - SBIN.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:19+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:19Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:19Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/SBIN.NS?period1=1577817000&period2=1723011199&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:19Z - DEBUG - SBIN.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:19Z - DEBUG - SBIN.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:19Z - DEBUG - SBIN.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:19Z - DEBUG - SBIN.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:19Z - DEBUG - Exiting history()
# 2024-08-07T11:43:19Z - INFO - Data for SBIN.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\SBIN.NS.csv
# 2024-08-07T11:43:19Z - INFO - Starting data processing for symbol: TATACHEM.NS
# 2024-08-07T11:43:19Z - DEBUG - Entering history()
# 2024-08-07T11:43:19Z - DEBUG - TATACHEM.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:19+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:19Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:20Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/TATACHEM.NS?period1=1577817000&period2=1723011199&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:20Z - DEBUG - TATACHEM.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-07 06:13:05
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:20Z - DEBUG - TATACHEM.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-07 11:43:05+05:30
# 2024-08-07T11:43:20Z - DEBUG - TATACHEM.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-07 00:00:00+05:30
# 2024-08-07T11:43:20Z - DEBUG - TATACHEM.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-07 00:00:00+05:30
# 2024-08-07T11:43:20Z - DEBUG - Exiting history()
# 2024-08-07T11:43:20Z - INFO - Data for TATACHEM.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\TATACHEM.NS.csv
# 2024-08-07T11:43:20Z - INFO - Starting data processing for symbol: TATAMOTORS.NS
# 2024-08-07T11:43:20Z - DEBUG - Entering history()
# 2024-08-07T11:43:20Z - DEBUG - TATAMOTORS.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:20+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:20Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:20Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/TATAMOTORS.NS?period1=1577817000&period2=1723011200&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:20Z - DEBUG - TATAMOTORS.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:20Z - DEBUG - TATAMOTORS.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:20Z - DEBUG - TATAMOTORS.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:20Z - DEBUG - TATAMOTORS.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:20Z - DEBUG - Exiting history()
# 2024-08-07T11:43:20Z - INFO - Data for TATAMOTORS.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\TATAMOTORS.NS.csv
# 2024-08-07T11:43:20Z - INFO - Starting data processing for symbol: TATAPOWER.NS
# 2024-08-07T11:43:20Z - DEBUG - Entering history()
# 2024-08-07T11:43:20Z - DEBUG - TATAPOWER.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:20+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:20Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:20Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/TATAPOWER.NS?period1=1577817000&period2=1723011200&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:20Z - DEBUG - TATAPOWER.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:20Z - DEBUG - TATAPOWER.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:20Z - DEBUG - TATAPOWER.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:20Z - DEBUG - TATAPOWER.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:20Z - DEBUG - Exiting history()
# 2024-08-07T11:43:20Z - INFO - Data for TATAPOWER.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\TATAPOWER.NS.csv
# 2024-08-07T11:43:20Z - INFO - Starting data processing for symbol: VOLTAS.NS
# 2024-08-07T11:43:20Z - DEBUG - Entering history()
# 2024-08-07T11:43:20Z - DEBUG - VOLTAS.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:20+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:20Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:21Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/VOLTAS.NS?period1=1577817000&period2=1723011200&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:21Z - DEBUG - VOLTAS.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:21Z - DEBUG - VOLTAS.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T11:43:21Z - DEBUG - VOLTAS.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:21Z - DEBUG - VOLTAS.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T11:43:21Z - DEBUG - Exiting history()
# 2024-08-07T11:43:21Z - INFO - Data for VOLTAS.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\VOLTAS.NS.csv
# 2024-08-07T11:43:21Z - INFO - Starting data processing for symbol: YESBANK.NS
# 2024-08-07T11:43:21Z - DEBUG - Entering history()
# 2024-08-07T11:43:21Z - DEBUG - YESBANK.NS: Yahoo GET parameters: {'period1': '2020-01-01 00:00:00+05:30', 'period2': '2024-08-07 11:43:21+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T11:43:21Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T11:43:21Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/YESBANK.NS?period1=1577817000&period2=1723011201&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T11:43:21Z - DEBUG - YESBANK.NS: yfinance received OHLC data: 2020-01-01 03:45:00 -> 2024-08-07 06:13:20
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T11:43:21Z - DEBUG - YESBANK.NS: OHLC after cleaning: 2020-01-01 09:15:00+05:30 -> 2024-08-07 11:43:20+05:30
# 2024-08-07T11:43:21Z - DEBUG - YESBANK.NS: OHLC after combining events: 2020-01-01 00:00:00+05:30 -> 2024-08-07 00:00:00+05:30
# 2024-08-07T11:43:21Z - DEBUG - YESBANK.NS: yfinance returning OHLC: 2020-01-01 00:00:00+05:30 -> 2024-08-07 00:00:00+05:30
# 2024-08-07T11:43:21Z - DEBUG - Exiting history()
# 2024-08-07T11:43:21Z - INFO - Data for YESBANK.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockPrice\YESBANK.NS.csv
