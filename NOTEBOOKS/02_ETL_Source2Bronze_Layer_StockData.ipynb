# %% [markdown]
# ## SOURCE TO BRONZE LAYER
#
# ### Process
#
# 1. **Determine Current Year**: The function calculates the current year to use as the end date for data fetching.
# 2. **Generate Year List**: Creates a list of years from the specified start year (`from_year`) to the current year.
# 3. **Data Fetching and Processing**:
#    - For each year in the list, the function fetches daily stock data using the Yahoo Finance API (`yfinance`).
#    - If data is retrieved successfully, it is processed by:
#      - Resetting the index to include the date as a column.
#      - Replacing punctuation in column names for consistency.
#      - Fixing duplicate column names by appending numerical suffixes.
#    - If no data is fetched for a year, a warning is logged.
# 4. **Directory and File Handling**:
#    - Ensures that a directory for each year exists or creates it if necessary.
#    - Saves the processed data to a CSV file in the appropriate year-specific directory.
# 5. **Error Handling**: Logs any errors encountered during the fetching, processing, or saving of data.

# %%
# Import necessary libraries and utility functions
from datetime import datetime
import yfinance as yf
from common.utilities import (
    fix_duplicate_column_names,
    global_path,
    logger,
    replace_punctuation_from_columns,
)

# %%
def process_file(symbol: str, filename: str, from_year: int) -> None:
    """
    Processes historical stock data for a given symbol and saves it to a CSV file.

    Parameters:
    - symbol (str): The stock symbol to fetch data for.
    - filename (str): The filename to save the processed data as.
    - from_year (int): The start year for which to fetch data.
    """
    # Determine the current year
    current_year = datetime.now().year

    # Generate a list of years from the given year to the current year
    years = list(range(from_year, current_year + 1))

    # Log the start of processing for the given symbol
    logger.info(
        f"Starting data processing for symbol: {symbol}, Years: {years}"
    )

    # Fetch historical stock data for each year
    for yr in years:
        start_date = f"{yr}-01-01"
        end_date = (
            f"{yr}-12-31"
            if yr < current_year
            else datetime.now().strftime("%Y-%m-%d")
        )

        try:
            # Fetch historical data from Yahoo Finance for the specified year
            stock = yf.Ticker(symbol)
            df = stock.history(start=start_date, end=end_date, interval="1d")

            # Check if the DataFrame is empty
            if df.empty:
                logger.warning(
                    f"No data fetched for symbol: {symbol} for year: {yr}"
                )
                continue

            # Reset the index to ensure date is a column
            df = df.reset_index()

            # Replace punctuation in column names for consistency
            df = replace_punctuation_from_columns(df)

            # Fix duplicate column names by appending numerical suffixes
            df = fix_duplicate_column_names(df)

            # Ensure the directory exists
            year_dir = global_path.stockdata_bronze_layer_path.joinpath(str(yr))
            year_dir.mkdir(parents=True, exist_ok=True)

            # Determine the output file path in the bronze layer
            output_file = year_dir.joinpath(filename)

            # Save the processed DataFrame to a CSV file
            df.to_csv(output_file, index=False)

            # Log successful processing and saving of data
            logger.info(
                f"Data for {symbol} successfully processed and saved to {output_file}"
            )

        except Exception as e:
            # Log any errors encountered during processing
            logger.error(
                f"Error processing data for {symbol} for year {yr}: {e}"
            )

# %%
# Dictionary mapping stock symbols to output filenames
symbols_to_files = {
    "0P00017844.BO": "MIRAE-ASSET-TAX-SAVER-DIRECT-GROWTH.MF.csv",
    "0P0000XVL9.BO": "SBI-MAGNUM-TAXGAIN-SCHEME-DIR-GR.MF.csv",
    "BHAGERIA.NS": "BHAGERIA.NS.csv",
    "BPCL.NS": "BPCL.NS.csv",
    "GOLDBEES.NS": "GOLDBEES.NS.csv",
    "HERANBA.NS": "HERANBA.NS.csv",
    "IDEA.NS": "IDEA.NS.csv",
    "INFY.NS": "INFY.NS.csv",
    "IRCTC.NS": "IRCTC.NS.csv",
    "KPITTECH.NS": "KPITTECH.NS.csv",
    "LICI.NS": "LICI.NS.csv",
    "NIFTYBEES.NS": "NIFTYBEES.NS.csv",
    "PNB.NS": "PNB.NS.csv",
    "SBIN.NS": "SBIN.NS.csv",
    "TATACHEM.NS": "TATACHEM.NS.csv",
    "TATAMOTORS.NS": "TATAMOTORS.NS.csv",
    "TATAPOWER.NS": "TATAPOWER.NS.csv",
    "VOLTAS.NS": "VOLTAS.NS.csv",
    "YESBANK.NS": "YESBANK.NS.csv",
}

# Iterate over each symbol and corresponding filename
for symbol, filename in symbols_to_files.items():
    process_file(symbol, filename, from_year=datetime.now().year)
# Out:
# 2024-08-07T13:56:35Z - INFO - Starting data processing for symbol: 0P00017844.BO, Years: [2024]
# 2024-08-07T13:56:35Z - DEBUG - Entering history()
# 2024-08-07T13:56:36Z - DEBUG - 0P00017844.BO: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:36Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:36Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/0P00017844.BO?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:36Z - DEBUG - 0P00017844.BO: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:36Z - DEBUG - 0P00017844.BO: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:36Z - DEBUG - 0P00017844.BO: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:36Z - DEBUG - 0P00017844.BO: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:36Z - DEBUG - Exiting history()
# 2024-08-07T13:56:36Z - INFO - Data for 0P00017844.BO successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\MIRAE-ASSET-TAX-SAVER-DIRECT-GROWTH.MF.csv
# 2024-08-07T13:56:36Z - INFO - Starting data processing for symbol: 0P0000XVL9.BO, Years: [2024]
# 2024-08-07T13:56:36Z - DEBUG - Entering history()
# 2024-08-07T13:56:36Z - DEBUG - 0P0000XVL9.BO: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:36Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:37Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/0P0000XVL9.BO?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:37Z - DEBUG - 0P0000XVL9.BO: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:37Z - DEBUG - 0P0000XVL9.BO: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - 0P0000XVL9.BO: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - 0P0000XVL9.BO: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - Exiting history()
# 2024-08-07T13:56:37Z - INFO - Data for 0P0000XVL9.BO successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\SBI-MAGNUM-TAXGAIN-SCHEME-DIR-GR.MF.csv
# 2024-08-07T13:56:37Z - INFO - Starting data processing for symbol: BHAGERIA.NS, Years: [2024]
# 2024-08-07T13:56:37Z - DEBUG - Entering history()
# 2024-08-07T13:56:37Z - DEBUG - BHAGERIA.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:37Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:37Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/BHAGERIA.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:37Z - DEBUG - BHAGERIA.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:37Z - DEBUG - BHAGERIA.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - BHAGERIA.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - BHAGERIA.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - Exiting history()
# 2024-08-07T13:56:37Z - INFO - Data for BHAGERIA.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\BHAGERIA.NS.csv
# 2024-08-07T13:56:37Z - INFO - Starting data processing for symbol: BPCL.NS, Years: [2024]
# 2024-08-07T13:56:37Z - DEBUG - Entering history()
# 2024-08-07T13:56:37Z - DEBUG - BPCL.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:37Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:37Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/BPCL.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:37Z - DEBUG - BPCL.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:37Z - DEBUG - BPCL.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - BPCL.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - BPCL.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - Exiting history()
# 2024-08-07T13:56:37Z - INFO - Data for BPCL.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\BPCL.NS.csv
# 2024-08-07T13:56:37Z - INFO - Starting data processing for symbol: GOLDBEES.NS, Years: [2024]
# 2024-08-07T13:56:37Z - DEBUG - Entering history()
# 2024-08-07T13:56:37Z - DEBUG - GOLDBEES.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:37Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:37Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/GOLDBEES.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:37Z - DEBUG - GOLDBEES.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:37Z - DEBUG - GOLDBEES.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - GOLDBEES.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - GOLDBEES.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:37Z - DEBUG - Exiting history()
# 2024-08-07T13:56:37Z - INFO - Data for GOLDBEES.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\GOLDBEES.NS.csv
# 2024-08-07T13:56:37Z - INFO - Starting data processing for symbol: HERANBA.NS, Years: [2024]
# 2024-08-07T13:56:37Z - DEBUG - Entering history()
# 2024-08-07T13:56:37Z - DEBUG - HERANBA.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:38Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:38Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/HERANBA.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:38Z - DEBUG - HERANBA.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:38Z - DEBUG - HERANBA.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:38Z - DEBUG - HERANBA.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:38Z - DEBUG - HERANBA.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:38Z - DEBUG - Exiting history()
# 2024-08-07T13:56:38Z - INFO - Data for HERANBA.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\HERANBA.NS.csv
# 2024-08-07T13:56:38Z - INFO - Starting data processing for symbol: IDEA.NS, Years: [2024]
# 2024-08-07T13:56:38Z - DEBUG - Entering history()
# 2024-08-07T13:56:38Z - DEBUG - IDEA.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:38Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:38Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/IDEA.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:38Z - DEBUG - IDEA.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:38Z - DEBUG - IDEA.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:38Z - DEBUG - IDEA.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:38Z - DEBUG - IDEA.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:38Z - DEBUG - Exiting history()
# 2024-08-07T13:56:38Z - INFO - Data for IDEA.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\IDEA.NS.csv
# 2024-08-07T13:56:38Z - INFO - Starting data processing for symbol: INFY.NS, Years: [2024]
# 2024-08-07T13:56:38Z - DEBUG - Entering history()
# 2024-08-07T13:56:38Z - DEBUG - INFY.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:38Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:38Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/INFY.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:38Z - DEBUG - INFY.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:38Z - DEBUG - INFY.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:38Z - DEBUG - INFY.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:38Z - DEBUG - INFY.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:38Z - DEBUG - Exiting history()
# 2024-08-07T13:56:38Z - INFO - Data for INFY.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\INFY.NS.csv
# 2024-08-07T13:56:38Z - INFO - Starting data processing for symbol: IRCTC.NS, Years: [2024]
# 2024-08-07T13:56:38Z - DEBUG - Entering history()
# 2024-08-07T13:56:38Z - DEBUG - IRCTC.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:38Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:39Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/IRCTC.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:39Z - DEBUG - IRCTC.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:39Z - DEBUG - IRCTC.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:39Z - DEBUG - IRCTC.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:39Z - DEBUG - IRCTC.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:39Z - DEBUG - Exiting history()
# 2024-08-07T13:56:39Z - INFO - Data for IRCTC.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\IRCTC.NS.csv
# 2024-08-07T13:56:39Z - INFO - Starting data processing for symbol: KPITTECH.NS, Years: [2024]
# 2024-08-07T13:56:39Z - DEBUG - Entering history()
# 2024-08-07T13:56:39Z - DEBUG - KPITTECH.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:39Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:39Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/KPITTECH.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:39Z - DEBUG - KPITTECH.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:39Z - DEBUG - KPITTECH.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:39Z - DEBUG - KPITTECH.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:39Z - DEBUG - KPITTECH.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:39Z - DEBUG - Exiting history()
# 2024-08-07T13:56:39Z - INFO - Data for KPITTECH.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\KPITTECH.NS.csv
# 2024-08-07T13:56:39Z - INFO - Starting data processing for symbol: LICI.NS, Years: [2024]
# 2024-08-07T13:56:39Z - DEBUG - Entering history()
# 2024-08-07T13:56:39Z - DEBUG - LICI.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:39Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:39Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/LICI.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:39Z - DEBUG - LICI.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:39Z - DEBUG - LICI.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:39Z - DEBUG - LICI.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:39Z - DEBUG - LICI.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:39Z - DEBUG - Exiting history()
# 2024-08-07T13:56:39Z - INFO - Data for LICI.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\LICI.NS.csv
# 2024-08-07T13:56:39Z - INFO - Starting data processing for symbol: NIFTYBEES.NS, Years: [2024]
# 2024-08-07T13:56:39Z - DEBUG - Entering history()
# 2024-08-07T13:56:39Z - DEBUG - NIFTYBEES.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:39Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:40Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/NIFTYBEES.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:40Z - DEBUG - NIFTYBEES.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:40Z - DEBUG - NIFTYBEES.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:40Z - DEBUG - NIFTYBEES.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:40Z - DEBUG - NIFTYBEES.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:40Z - DEBUG - Exiting history()
# 2024-08-07T13:56:40Z - INFO - Data for NIFTYBEES.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\NIFTYBEES.NS.csv
# 2024-08-07T13:56:40Z - INFO - Starting data processing for symbol: PNB.NS, Years: [2024]
# 2024-08-07T13:56:40Z - DEBUG - Entering history()
# 2024-08-07T13:56:40Z - DEBUG - PNB.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:40Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:40Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/PNB.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:40Z - DEBUG - PNB.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:40Z - DEBUG - PNB.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:40Z - DEBUG - PNB.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:40Z - DEBUG - PNB.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:40Z - DEBUG - Exiting history()
# 2024-08-07T13:56:40Z - INFO - Data for PNB.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\PNB.NS.csv
# 2024-08-07T13:56:40Z - INFO - Starting data processing for symbol: SBIN.NS, Years: [2024]
# 2024-08-07T13:56:40Z - DEBUG - Entering history()
# 2024-08-07T13:56:40Z - DEBUG - SBIN.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:40Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:40Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/SBIN.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:40Z - DEBUG - SBIN.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:40Z - DEBUG - SBIN.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:40Z - DEBUG - SBIN.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:40Z - DEBUG - SBIN.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:40Z - DEBUG - Exiting history()
# 2024-08-07T13:56:40Z - INFO - Data for SBIN.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\SBIN.NS.csv
# 2024-08-07T13:56:40Z - INFO - Starting data processing for symbol: TATACHEM.NS, Years: [2024]
# 2024-08-07T13:56:40Z - DEBUG - Entering history()
# 2024-08-07T13:56:40Z - DEBUG - TATACHEM.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:40Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:41Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/TATACHEM.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:41Z - DEBUG - TATACHEM.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:41Z - DEBUG - TATACHEM.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:41Z - DEBUG - TATACHEM.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:41Z - DEBUG - TATACHEM.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:41Z - DEBUG - Exiting history()
# 2024-08-07T13:56:41Z - INFO - Data for TATACHEM.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\TATACHEM.NS.csv
# 2024-08-07T13:56:41Z - INFO - Starting data processing for symbol: TATAMOTORS.NS, Years: [2024]
# 2024-08-07T13:56:41Z - DEBUG - Entering history()
# 2024-08-07T13:56:41Z - DEBUG - TATAMOTORS.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:41Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:41Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/TATAMOTORS.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:41Z - DEBUG - TATAMOTORS.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:41Z - DEBUG - TATAMOTORS.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:41Z - DEBUG - TATAMOTORS.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:41Z - DEBUG - TATAMOTORS.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:41Z - DEBUG - Exiting history()
# 2024-08-07T13:56:41Z - INFO - Data for TATAMOTORS.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\TATAMOTORS.NS.csv
# 2024-08-07T13:56:41Z - INFO - Starting data processing for symbol: TATAPOWER.NS, Years: [2024]
# 2024-08-07T13:56:41Z - DEBUG - Entering history()
# 2024-08-07T13:56:41Z - DEBUG - TATAPOWER.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:41Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:41Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/TATAPOWER.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:41Z - DEBUG - TATAPOWER.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:41Z - DEBUG - TATAPOWER.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:41Z - DEBUG - TATAPOWER.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:42Z - DEBUG - TATAPOWER.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:42Z - DEBUG - Exiting history()
# 2024-08-07T13:56:42Z - INFO - Data for TATAPOWER.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\TATAPOWER.NS.csv
# 2024-08-07T13:56:42Z - INFO - Starting data processing for symbol: VOLTAS.NS, Years: [2024]
# 2024-08-07T13:56:42Z - DEBUG - Entering history()
# 2024-08-07T13:56:42Z - DEBUG - VOLTAS.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:42Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:42Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/VOLTAS.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:42Z - DEBUG - VOLTAS.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:42Z - DEBUG - VOLTAS.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:42Z - DEBUG - VOLTAS.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:42Z - DEBUG - VOLTAS.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:42Z - DEBUG - Exiting history()
# 2024-08-07T13:56:42Z - INFO - Data for VOLTAS.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\VOLTAS.NS.csv
# 2024-08-07T13:56:42Z - INFO - Starting data processing for symbol: YESBANK.NS, Years: [2024]
# 2024-08-07T13:56:42Z - DEBUG - Entering history()
# 2024-08-07T13:56:42Z - DEBUG - YESBANK.NS: Yahoo GET parameters: {'period1': '2024-01-01 00:00:00+05:30', 'period2': '2024-08-07 00:00:00+05:30', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# 2024-08-07T13:56:42Z - DEBUG - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-08-07T13:56:42Z - DEBUG - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/YESBANK.NS?period1=1704047400&period2=1722969000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains HTTP/1.1" 200 None
# 2024-08-07T13:56:42Z - DEBUG - YESBANK.NS: yfinance received OHLC data: 2024-01-01 03:45:00 -> 2024-08-06 03:45:00
# c:\Users\prashant.tripathi\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:768: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# 2024-08-07T13:56:42Z - DEBUG - YESBANK.NS: OHLC after cleaning: 2024-01-01 09:15:00+05:30 -> 2024-08-06 09:15:00+05:30
# 2024-08-07T13:56:42Z - DEBUG - YESBANK.NS: OHLC after combining events: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:42Z - DEBUG - YESBANK.NS: yfinance returning OHLC: 2024-01-01 00:00:00+05:30 -> 2024-08-06 00:00:00+05:30
# 2024-08-07T13:56:42Z - DEBUG - Exiting history()
# 2024-08-07T13:56:42Z - INFO - Data for YESBANK.NS successfully processed and saved to C:\Users\prashant.tripathi\Code\Upstox\DATA\BRONZE\StockData\2024\YESBANK.NS.csv
